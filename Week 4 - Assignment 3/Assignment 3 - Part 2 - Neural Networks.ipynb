# %%
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from funs import sigmoid, DisplayData, Predict

# %% [markdown]
# ##### Loading and visualizing data

# %%
img = loadmat("ex3data1.mat", verify_compressed_data_integrity = True)
img.keys()
x = img.get("X")
y = img.get("y").reshape(-1,1)

DisplayData(x)

# %% [markdown]
# ##### Loading the weights

# %%
weights = loadmat("ex3weights.mat", verify_compressed_data_integrity = True)
Theta1 = weights.get('Theta1')
Theta2 = weights.get('Theta2')

# %% [markdown]
# ##### Predicting the digits

# %%
pred = Predict(Theta1, Theta2, x)
print(f'Accuracy achieved : {(pred == y).mean()*100}%')
# Out:
# Accuracy achieved : 97.52%
